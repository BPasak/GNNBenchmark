# %%
from Benchmarks.ParameterMeasurement import countParameters
from Models.ExampleModel import ExampleModel

exampleModel = ExampleModel()

parameter_count = countParameters(exampleModel)
print(parameter_count)
# Out:
# 110
